# %% [markdown]
# # Bitcoin Analysis

# %%
# dependencies
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# store file path
path = os.path.join('bitcoin_data.csv')

# store in dataframe
df = pd.read_csv(path)

df.head()
# Out:
#         Date  Period        Open         High         Low        Close  \
# 0   1/1/2017       1  963.380005  1150.630005  806.659973   888.869995
# 1   1/8/2017       2  888.869995   936.130005  739.549988   819.630005
# 2  1/15/2017       3  819.630005   928.929993  808.630005   919.840027
# 3  1/22/2017       4  919.840027   938.380005  883.630005   918.510010
# 4  1/29/2017       5  918.510010  1041.040039  911.510010  1031.849976
#
#      Adj Close     Volume
# 0   888.869995  870316976
# 1   819.630005  538236894
# 2   919.840027  305189873
# 3   918.510010  234369803
# 4  1031.849976  277195041

# %%
# plot
x = df['Period']
y1 = df['Adj Close']
y2 = df['Volume']
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')
ax1.set_xlabel('Week')
ax1.set_ylabel('Adjusted Close Price', color='g')
ax2.set_ylabel('Volume', color='b')
plt.title('Adjusted Close Price vs. Volume of Bitcoin over 2017')
fig.set_size_inches(18.5, 10.5)
plt.savefig('bitcoin_price_vs_volume.png')
plt.show()

# %%
# add empty column
df['Percentage Change in Volume'] = ''
df['Percentage Change in Price'] = ''

# Calculate percentage changes
df['Percentage Change in Volume'] = df['Volume'].pct_change()
df['Percentage Change in Price'] = df['Adj Close'].pct_change()

df.to_csv('bitcoin_results.csv')

df.head()
# Out:
#         Date  Period        Open         High         Low        Close  \
# 0   1/1/2017       1  963.380005  1150.630005  806.659973   888.869995
# 1   1/8/2017       2  888.869995   936.130005  739.549988   819.630005
# 2  1/15/2017       3  819.630005   928.929993  808.630005   919.840027
# 3  1/22/2017       4  919.840027   938.380005  883.630005   918.510010
# 4  1/29/2017       5  918.510010  1041.040039  911.510010  1031.849976
#
#      Adj Close     Volume  Percentage Change in Volume  \
# 0   888.869995  870316976                          NaN
# 1   819.630005  538236894                    -0.381562
# 2   919.840027  305189873                    -0.432982
# 3   918.510010  234369803                    -0.232052
# 4  1031.849976  277195041                     0.182725
#
#    Percentage Change in Price
# 0                         NaN
# 1                   -0.077897
# 2                    0.122263
# 3                   -0.001446
# 4                    0.123395

# %%
# plot
x = df['Period']
y1 = df['Percentage Change in Price']
y2 = df['Percentage Change in Volume']
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-')
ax2.plot(x, y2, 'b-')
ax1.set_xlabel('Week')
ax1.set_ylabel('% Change in Price', color='g')
ax2.set_ylabel('% Change in Volume', color='b')
plt.title('% Change in Price vs. % Change in Volume of Bitcoin Over 2017')
fig.set_size_inches(18.5, 10.5)
plt.savefig('bitcoin_percent_changes.png')
plt.show()
